# %%
import sys
sys.path.append('../src')
from data_loader import load_news_data
from eda import descriptive_stats, time_series_analysis, publisher_analysis, topic_modeling
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Amdemichael\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Load data
news_df = pd.read_csv('../data/raw_analyst_ratings.csv')  # Adjust path if needed
news_df['date'] = pd.to_datetime(news_df['date'], format='%Y-%m-%d %H:%M:%S', errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Load data
# ----> 2 news_df = pd.read_csv('../data/raw_analyst_ratings.csv')  # Adjust path if needed
#       3 news_df['date'] = pd.to_datetime(news_df['date'], format='%Y-%m-%d %H:%M:%S', errors='coerce')
#
# NameError: name 'pd' is not defined

# %%
# Descriptive Statistics
stats = descriptive_stats(news_df)
print("Headline Length Stats:\n", stats['headline_length_stats'])
print("Articles per Publisher:\n", stats['articles_per_publisher'])
# Out:
# Headline Length Stats:
#  count    1.407328e+06
# mean     7.312051e+01
# std      4.073531e+01
# min      3.000000e+00
# 25%      4.700000e+01
# 50%      6.400000e+01
# 75%      8.700000e+01
# max      5.120000e+02
# Name: headline_length, dtype: float64
# Articles per Publisher:
#  publisher
# Paul Quintaro        228373
# Lisa Levin           186979
# Benzinga Newsdesk    150484
# Charles Gross         96732
# Monica Gerson         82380
#                       ...
# MoneyGeek                 1
# muathe                    1
# Robert Morris             1
# LeftCoastHedgie           1
# Jeremie Capron            1
# Name: count, Length: 1034, dtype: int64

# %%
# Time Series Analysis
time_series_analysis(news_df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 2
#       1 # Time Series Analysis
# ----> 2 time_series_analysis(news_df)
#
# File d:\Tutorials\KAIM\Week 1\Predicting-Price-Moves-with-News-Sentiment\notebooks\../src\eda.py:27, in time_series_analysis(df, output_dir)
#      25 plt.xlabel('Date')
#      26 plt.ylabel('Number of Articles')
# ---> 27 plt.savefig(f'{output_dir}/publication_frequency.png')
#      28 plt.close()
#
# File d:\Tutorials\KAIM\Week 1\Predicting-Price-Moves-with-News-Sentiment\taenv\Lib\site-packages\matplotlib\pyplot.py:1251, in savefig(*args, **kwargs)
#    1248 fig = gcf()
#    1249 # savefig default implementation has no return, so mypy is unhappy
#    1250 # presumably this is here because subclasses can return?
# -> 1251 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
# ...

# %%
# Publisher Analysis
top_publishers = publisher_analysis(news_df)
print("Top Publishers:\n", top_publishers)
# Out:
# Top Publishers:
#  publisher
# Paul Quintaro        228373
# Lisa Levin           186979
# Benzinga Newsdesk    150484
# Charles Gross         96732
# Monica Gerson         82380
# Eddie Staley          57254
# Hal Lindon            49047
# ETF Professor         28489
# Juan Lopez            28438
# Benzinga Staff        28114
# Name: count, dtype: int64

# %%
# Topic Modeling
import nltk
nltk.download('punkt')

keywords = topic_modeling(news_df)
print("Top Keywords:\n", keywords)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Amdemichael\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[37], line 5
#       2 import nltk
#       3 nltk.download('punkt')
# ----> 5 keywords = topic_modeling(news_df)
#       6 print("Top Keywords:\n", keywords)
#
# File d:\Tutorials\KAIM\Week 1\Predicting-Price-Moves-with-News-Sentiment\notebooks\../src\eda.py:38, in topic_modeling(df, num_keywords)
#      36 def topic_modeling(df, num_keywords=10):
#      37     """Extract common keywords from headlines."""
# ---> 38     headlines = df['headline'].str.lower()
#      39     tokens = headlines.apply(word_tokenize)
#      40     all_tokens = [token for sublist in tokens for token in sublist]
#
# ...

# %%
import nltk
nltk.download('punkt')

from nltk.tokenize import word_tokenize
word_tokenize("Hello, world!")  # Should return ['Hello', ',', 'world', '!']
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Amdemichael\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[41], line 5
#       2 nltk.download('punkt')
#       4 from nltk.tokenize import word_tokenize
# ----> 5 word_tokenize("Hello, world!")  # Should return ['Hello', ',', 'world', '!']
#
# File d:\Tutorials\KAIM\Week 1\Predicting-Price-Moves-with-News-Sentiment\taenv\Lib\site-packages\nltk\tokenize\__init__.py:142, in word_tokenize(text, language, preserve_line)
#     127 def word_tokenize(text, language="english", preserve_line=False):
#     128     """
#     129     Return a tokenized copy of *text*,
#     130     using NLTK's recommended word tokenizer
#    (...)    140     :type preserve_line: bool
#     141     """
# ...
