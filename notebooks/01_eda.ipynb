# %%
import sys
import pandas as pd
sys.path.append('../src')
from data_loader import load_news_data
from eda import descriptive_stats, time_series_analysis, publisher_analysis, topic_modeling

# %%
# Load data
news_df = pd.read_csv('../data/raw_analyst_ratings.csv')  # Adjust path if needed
news_df['date'] = pd.to_datetime(news_df['date'], format='%Y-%m-%d %H:%M:%S', errors='coerce')

# %%
# Time Series Analysis
time_series_analysis(news_df)

# %%
# Publisher Analysis
top_publishers = publisher_analysis(news_df)
print("Top Publishers:\n", top_publishers)
# Out:
# d:\Tutorials\KAIM\Week 1\Predicting-Price-Moves-with-News-Sentiment\notebooks\../src\eda.py:84: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_publishers.index, y=top_10_publishers.values, palette='viridis')
# Top Publishers:
#  publisher
# Paul Quintaro        224161
# Lisa Levin           174571
# Benzinga Newsdesk    135734
# Charles Gross         94942
# Monica Gerson         81769
# Eddie Staley          56251
# Hal Lindon            47577
# Juan Lopez            28399
# Benzinga Staff        28108
# ETF Professor         24127
# Name: count, dtype: int64

# %%
# Topic Modeling
keywords = topic_modeling(news_df)
print("Top Keywords:\n", keywords)
# Out:
# Top Keywords:
#  {'top_keywords': [('vs', 159573), ('stocks', 149072), ('est', 138850), ('eps', 123399), ('shares', 105834), ('reports', 105691), ('update', 89559), ('market', 86855), ('earnings', 84899), ('top', 77227)], 'top_bigrams': [(('vs', 'est'), 127765), (('eps', 'vs'), 69022), (('reports', 'eps'), 50274), (('benzingas', 'top'), 43340), (('price', 'target'), 42681)]}
