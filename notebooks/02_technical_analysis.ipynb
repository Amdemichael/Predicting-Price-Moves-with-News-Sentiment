# %%
import sys
sys.path.append('../src')
import pandas as pd
from data_loader import load_stock_data
from technical_indicators import calculate_indicators, visualize_indicators

# %%
# Load stock data
stock_df = load_stock_data('../data/AAPL_historical_data.csv')
stock_df['Date'] = pd.to_datetime(stock_df['Date'], format='%Y-%m-%d %H:%M:%S', errors='coerce')

# %%
# Calculate indicators
indicators = calculate_indicators(stock_df)

# %%
# Visualize
visualize_indicators(stock_df, indicators)
